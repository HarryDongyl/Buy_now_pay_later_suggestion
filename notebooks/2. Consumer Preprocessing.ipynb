# %% [markdown]
# # 2. Consumer Data Preprocessing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
consumer = pd.read_csv('../data/curated/consumer/consumer_merge.csv')

# %% [markdown]
# ## 2.1 Visualization of consumer feature

# %%
custom_colors = ['#dd6e42', '#e8dab2','#c0d6df','#b5b682', '#7c9885', '#eaeaea','#b56576','#6d597a']
consumer['state'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(10, 10), colors=custom_colors)
plt.xlabel('State')
plt.ylabel('Number of Consumers')
plt.title('State Distribution of Consumers')
plt.savefig('../plots/state distribution of consumers.png')
plt.show()

# %% [markdown]
# The fraud_probability (both merchant and consumer) is far less than sufficient
# to pair the transcations, or even to pair the merchants.
# The order_datatime is also limited.
#
# Should hold a predict model on the fraud_probability base on current given dataset to predict the left.
